# %%
import pandas as pd

# %%
brookhaven_data = pd.read_csv("../output/msg_extracts.csv")

# %%
print(brookhaven_data)
# Out:
#                                 subject                             date  \
# 0    A Resident Posted a Crime Incident  Wed, 17 Nov 2021 18:16:36 -0500
# 1    A Resident Posted a Crime Incident  Mon, 17 May 2021 08:38:51 -0400
# 2    A Resident Posted a Crime Incident  Thu, 20 May 2021 23:47:46 -0400
# 3    A Resident Posted a Crime Incident  Sat, 09 Oct 2021 07:09:43 -0400
# 4    A Resident Posted a Crime Incident  Thu, 10 Jun 2021 07:49:36 -0400
# ..                                  ...                              ...
# 489  A Resident Posted a Crime Incident  Fri, 03 Sep 2021 19:34:46 -0400
# 490  A Resident Posted a Crime Incident  Thu, 20 May 2021 23:47:47 -0400
# 491  A Resident Posted a Crime Incident  Thu, 20 May 2021 23:47:57 -0400
# 492  A Resident Posted a Crime Incident  Tue, 02 Mar 2021 03:51:24 -0500
# 493  A Resident Posted a Crime Incident  Fri, 23 Jul 2021 14:58:41 -0400
#
#                                             sender  \
# ...

# %%
brookhaven_data.dtypes
# Out:
# subject                      object
# date                         object
# sender                       object
# to                           object
# cc                          float64
# body_title_top               object
# body_link1_title             object
# body_post_classification     object
# body_title                   object
# body_date                    object
# body_description             object
# body_link2_title             object
# body_link3_title             object
# body_full                    object
# file_name                    object
# dtype: object
